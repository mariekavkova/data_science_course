# %% [markdown]
# # My Jupyter notebook on IBM Watson studio

# %% [markdown]
# **Marie Kavková**
# <p>Aspiring data scientist

# %% [markdown]
# *I originally intended to be a part of a scientific group focusing on exploring human behavior using various technologies, such as AI. I realized I need more experience in IT and decided to find a job in an IT consulting company, hopefully as data scientist.*

# %% [markdown]
# ### This code is supposed to wish you a lucky day after inserting your name as an input.

# %%
name = input("Please tell us your name: ")
text = "I hope today will be your lucky day,"
print(text, name)

# %% [markdown]
# >Illustration by Kay Nielsen for the collection of fairy tales East of the Sun West of the Moon from 1914:
# ![73E5237D-20E5-41BD-9B5B-42879F720F6E_1_201_a.jpeg](attachment:73E5237D-20E5-41BD-9B5B-42879F720F6E_1_201_a.jpeg)
# [Kay Nielsen on wikipedia](https://en.wikipedia.org/wiki/Kay_Nielsen)
